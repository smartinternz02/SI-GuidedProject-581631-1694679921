# %% [markdown]
# #ASSIGNMENT -1

# %% [markdown]
# #Task - 1 Create a pandas dataframe (DataFrame name as 'df') (10 observation and 5 features)

# %%
import pandas as pd

# %%
df={'chocolate id':[101,102,103,104,105,106,107,108,109,110],
    'chocolate name':['Lindt Excellence','Ghirardelli Intense','Toblerone','Valrhona Guanaja','Cadbury Dairy Milk','Godiva Dark','Hersheys Special Dark','Côte dOr','Ritter Sport','Green & Blacks'],
    'Produced Country':['Switzerland','USA','Switzerland','France','UK','Belgium','USA','Belgium','Germany','UK'],
    'Cocoa Percentage':[70,72,50,70,20,72,45,86,50,70],
    'Found year':['1845','1852','1908','1922','1905','1926','1939','1883','1912','1991']}

# %%
df1=pd.DataFrame(df)

# %%
df1
# Out:
#    chocolate id         chocolate name Produced Country  Cocoa Percentage  \
# 0           101       Lindt Excellence      Switzerland                70
# 1           102    Ghirardelli Intense              USA                72
# 2           103              Toblerone      Switzerland                50
# 3           104       Valrhona Guanaja           France                70
# 4           105     Cadbury Dairy Milk               UK                20
# 5           106            Godiva Dark          Belgium                72
# 6           107  Hersheys Special Dark              USA                45
# 7           108               Côte dOr          Belgium                86
# 8           109           Ritter Sport          Germany                50
# 9           110         Green & Blacks               UK                70
#
#   Found year
# 0       1845
# 1       1852
# 2       1908
# 3       1922
# 4       1905
# 5       1926
# 6       1939
# 7       1883
# 8       1912
# ...

# %% [markdown]
# #Task- 2 Check the info of 'df'

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   chocolate id      10 non-null     int64
#  1   chocolate name    10 non-null     object
#  2   Produced Country  10 non-null     object
#  3   Cocoa Percentage  10 non-null     int64
#  4   Found year        10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %% [markdown]
# #Task 3- Check the descriptive statistics of 'df'

# %%
df1.describe()
# Out:
#        chocolate id  Cocoa Percentage
# count      10.00000         10.000000
# mean      105.50000         60.500000
# std         3.02765         19.109335
# min       101.00000         20.000000
# 25%       103.25000         50.000000
# 50%       105.50000         70.000000
# 75%       107.75000         71.500000
# max       110.00000         86.000000

# %% [markdown]
# #Task 4- check the 4th index observation with 'loc' slicing operator.

# %%
df1.loc[4]
# Out:
# chocolate id                       105
# chocolate name      Cadbury Dairy Milk
# Produced Country                    UK
# Cocoa Percentage                    20
# Found year                        1905
# Name: 4, dtype: object

# %% [markdown]
# #Task 5 - Check the null values in your 'df'

# %%
df1.isnull().sum()
# Out:
# chocolate id        0
# chocolate name      0
# Produced Country    0
# Cocoa Percentage    0
# Found year          0
# dtype: int64
